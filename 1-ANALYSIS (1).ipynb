# %%
#1. create a percentage column
#2. takeout all the male > 50%
#3. takeout all the male < 50%
#4. takeout all the female > 50%
#5. takeout all the female <50%
#6. calculate female cadet
#7. calculate male cadet
#8. parents educatioon are bachelor level
#9. male & female in standard lunch
#10. male & female in free lunch

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\User\Downloads\StudentsPerformance.csv")

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ## create a column for percentage

# %%
data["percentage"]=(data["math score"]+data["reading score"]+data["writing score"])/3

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# ## 2. Take out all the male>50%

# %%
male_50=data.loc[(data["percentage"]>50) & (data["gender"]=="male")]
male_50['percentage'].count()
# Out:
# 417

# %% [markdown]
# ## 3.Take out all the male<50%

# %%
male_50=data.loc[(data["percentage"]<50) & (data["gender"]=="male")]
male_50['percentage'].count()
# Out:
# 64

# %% [markdown]
# ## 4.Take out all the female>50%

# %%
female_50=data.loc[(data["percentage"]>50) & (data["gender"]=="female")]
female_50['percentage'].count()
# Out:
# 474

# %% [markdown]
# ## 5.Take out all the female<50%

# %%
female_50=data.loc[(data["percentage"]<50) & (data["gender"]=="female")]
female_50['percentage'].count()
# Out:
# 39

# %% [markdown]
# ## 6.calculate female candidates

# %%
female_count=data.loc[(data["gender"]=="female")]
female_count['gender'].count()
# Out:
# 518

# %% [markdown]
# ## 7.calculate male candidates

# %%
male_count=data.loc[data["gender"]=="male"]
male_count['gender'].count()
# Out:
# 482

# %% [markdown]
# ## 8.HOW MANY STUDENTS PARENT LEVEL OF EDUCATION IS BACHELORS

# %%
parent_edu=data.loc[data["parental level of education"] == "bachelor's degree"]
parent_edu['parental level of education'].size
# Out:
# 118

# %% [markdown]
# ## 9. HOW MANY STUDENTS PARENT LEVEL OF EDUCATION IS SOME COLLEGE

# %%
parent_edu1=data.loc[data["parental level of education"] == "some college"]
parent_edu1['parental level of education'].count()
# Out:
# 226

# %% [markdown]
# ## 10. Male in standard lunch

# %%
standard_lunch=data.loc[(data["lunch"]=="standard") & (data["gender"] == "male")]
len(standard_lunch)
# Out:
# 316

# %%
standard_lunch=data.loc[(data["lunch"]=="standard") & (data["gender"] == "male")]
standard_lunch
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 4     male        group C                some college  standard
# 10    male        group C          associate's degree  standard
# 11    male        group D          associate's degree  standard
# 13    male        group A                some college  standard
# 16    male        group C                 high school  standard
# ..     ...            ...                         ...       ...
# 981   male        group D            some high school  standard
# 982   male        group B            some high school  standard
# 985   male        group A                 high school  standard
# 987   male        group E            some high school  standard
# 994   male        group A                 high school  standard
#
#     test preparation course  math score  reading score  writing score  \
# 4                      none          76             78             75
# ...

# %% [markdown]
# ## 11.Female in standard lunch

# %%
standard_lunch1=data.loc[(data["lunch"]=="standard") & (data["gender"]=="female")]
len(standard_lunch1)
# Out:
# 329

# %%
standard_lunch1=data.loc[(data["lunch"]=="standard") & (data["gender"]=="female")]
standard_lunch1
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 5    female        group B          associate's degree  standard
# 6    female        group B                some college  standard
# ..      ...            ...                         ...       ...
# 984  female        group C            some high school  standard
# 986  female        group C          associate's degree  standard
# 991  female        group B            some high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %% [markdown]
# ## 12.Male in free lunch

# %%
free_lunch=data.loc[(data["lunch"]=="free/reduced") & (data["gender"]=="male")]
free_lunch
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 18    male        group C             master's degree  free/reduced
# 24    male        group D           bachelor's degree  free/reduced
# ..     ...            ...                         ...           ...
# 943   male        group A            some high school  free/reduced
# 948   male        group B            some high school  free/reduced
# 976   male        group B                some college  free/reduced
# 990   male        group E                 high school  free/reduced
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 3                      none          47             57             44
# ...

# %% [markdown]
# ## 13.Female in free lunch

# %%
free_lunch=data.loc[(data["lunch"]=="free/reduced") & (data["gender"]=="female")]
free_lunch
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 19   female        group C          associate's degree  free/reduced
# 21   female        group B                some college  free/reduced
# 32   female        group E             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 989  female        group D                some college  free/reduced
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...
